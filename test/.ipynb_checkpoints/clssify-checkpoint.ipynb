# %% [markdown]
# # 텍스트 감정 분류기 만들기

# %%
import os
from textblob.classifiers import NaiveBayesClassifier
from konlpy.tag import Mecab
pos_tagger = Mecab()

# %% [markdown]
# ## 학습 데이터

# %%
train_data = []
for root, dirs, files in os.walk('data'):
    # 파일 모두 읽기
    for fname in files:
        full_fname = os.path.join(root, fname) # 읽을 파일 전체 경로
        directorySeq = root.split('/')[1] # 디렉토리=카테고리
        text = open(full_fname, 'r').read() # 파일 읽기
        pos_tag = ['/'.join(token) for token in pos_tagger.pos(text)] # 형태소 분석
        data = (pos_tag, directorySeq)
        train_data.append(data) # 학습 데이터에 추가하기

# %% [markdown]
# ## 학습하기

# %%
cl = NaiveBayesClassifier(train_data)

# %% [markdown]
# ## 분류기준 살펴보기

# %%
cl.show_informative_features(5)
# Out:
# (['안녕/NNG',
#   '하/XSV',
#   '세요/EP+EF',
#   '청초/NNG',
#   '라/VCP+EC',
#   '음/IC',
#   '주인장/NNG',
#   '라희/NNP',
#   '입니다/VCP+EF',
#   ':/SC',
#   ')/SSC',
#   '접촉/NNG',
#   '성/XSN',
#   '피부염/NNG',
#   '지루/XR',
#   '성/XSN',
#   '피부염/NNG',
#   '화장품/NNG',
#   '부작용/NNG',
#   '눈/NNG',
#   '내리/VV',
#   '는/ETM',
#   '날/NNG',
#   '이/JKS',
#   '계속/MAG',
#   '이어지/VV',
#   '고/EC',
#   '있/VX',
#   '네요/EF',
#   './SF',
#   '감기/NNG',
#   '꼭/MAG',
#   '조심/NNG',
#   '하/XSV',
#   '시/EP',
#   '길/ETN+JKO',
#   '바랍니다/VV+EF',
#   './SF',
#   '열심히/MAG',
#   '2/SN',
#   'L/SL',
#   '를/JKO',
#   '매일/MAG',
#   '꾸준히/MAG',
#   '마시/VV',
#   '는/ETM',
#   '습관/NNG',
#   '을/JKO',
#   '도입/NNG',
#   '하/XSV',
#   '면서/EC',
#   '눈/NNG',
#   '에/JKB',
#   '띄/VV',
#   '게/EC',
#   '피부/NNG',
#   '가/JKS',
#   '작년/NNG',
#   '과/JC',
#   '재작년/NNG',
#   '겨울/NNG',
#   '과/JC',
#   '비교/NNG',
#   '했/XSV+EP',
#   '을/ETM',
#   '때/NNG',
#   '피부/NNG',
#   '가/JKS',
#   '촉촉/XR',
#   '해진/XSA+EC+VX+ETM',
#   '것/NNB',
#   '을/JKO',
#   '보/VV',
#   '고/EC',
#   ',/SC',
#   '저희/NP',
#   '어머니/NNG',
#   '께서/JKS',
#   '며칠/NNG',
#   '따라/VV+EC',
#   '하/VX',
#   '시/EP',
#   '다가/EC',
#   '배/NNG',
#   '에서/JKB',
#   '물소리/NNG',
#   '가/JKS',
#   '나/NP',
#   '서/JKB',
#   '그만두/VV',
#   '게/EC',
#   '되/VV',
#   '었/EP',
#   '습니다/EF',
#   './SF',
#   '참고/NNG',
#   '로/JKB',
#   '저희/NP',
#   '어머니/NNG',
#   '위/NNG',
#   '건강/NNG',
#   '이/JKS',
#   '그다지/MAG',
#   '좋/VA',
#   '은/ETM',
#   '편/NNB',
#   '이/JKC',
#   '아닙니다/VCN+EF',
#   './SF',
#   '역시/MAJ',
#   '뭐/NP',
#   '든/VCP+EC',
#   '건강/NNG',
#   '이/JKS',
#   '받쳐/VV+EC',
#   '주/VX',
#   '어야/EC',
#   '부작용/NNG',
#   '을/JKO',
#   '보/VV',
#   '지/EC',
#   '않/VX',
#   '는/ETM',
#   '것/NNB',
#   '같/VA',
#   '습니다/EF',
#   './SF',
#   '저/NP',
#   '도/JX',
#   '일전/NNG',
#   '에/JKB',
#   '무리/NNG',
#   '하/XSV',
#   '게/EC',
#   '물/NNG',
#   '마시/VV',
#   '는/ETM',
#   '양/NNG',
#   '을/JKO',
#   '늘리/VV',
#   '면/EC',
#   '꼭/MAG',
#   '몸/NNG',
#   '이/JKS',
#   '전체/NNG',
#   '적/XSN',
#   '으로/JKB',
#   '부어서/VV+EC',
#   '실천/NNG',
#   '을/JKO',
#   '못/MAG',
#   '했었/VV+EP',
#   '는데요/EF',
#   './SF',
#   '건강/NNG',
#   '이/JKS',
#   '대폭/MAG',
#   '좋/VA',
#   '아/EC',
#   '지/VX',
#   '니/EC',
#   '물마/NNG',
#   '시기/NNG',
#   '의/JKG',
#   '효과/NNG',
#   '만/JX',
#   '쏙쏙/MAG',
#   '-/SY',
#   '뽑/VV',
#   '아/EC',
#   '가/VX',
#   '는/ETM',
#   '것/NNB',
#   '같/VA',
#   '다는/ETM',
#   '느낌/NNG',
#   '이/JKS',
#   '듭니다/UNKNOWN',
#   './SF',
#   '[/SSO',
#   '청초/NNG',
#   '라/VCP+EC',
#   '음/NNG',
#   ']/SSC',
#   '곡식/NNG',
#   '찜/NNG',
#   '질/XSN',
#   '팩/MAG',
#   '//SC',
#   '유기농/NNG',
#   '현미/NNG',
#   '찜/NNG',
#   '질/XSN',
#   '팩/MAG',
#   '//SC',
#   '복부/NNG',
#   '찜/NNG',
#   '질/XSN',
#   '팩/MAG',
#   ':/SC',
#   '청초/NNG',
#   '라/VCP+EC',
#   '음/NNG',
#   '[/SSO',
#   '청초/NNG',
#   '라/VCP+EC',
#   '음/NNG',
#   ']/SSC',
#   '건강/NNG',
#   '한/XSA+ETM',
#   '라이프/NNG',
#   '스타일/NNG',
#   '을/JKO',
#   '꿈꾸/VV',
#   '는/ETM',
#   '공간/NNG',
#   '청초/NNG',
#   '라/VCP+EC',
#   '음/NNG',
#   '에/JKB',
#   '오/VV',
#   '신/EP+ETM',
#   '것/NNB',
#   '을/JKO',
#   '환영/NNG',
#   '합니다/XSV+EF',
#   ':/SC',
#   ')/SSC',
#   'm/SL',
#   './SY',
#   'smartstore/SL',
#   './SY',
#   'naver/SL',
#   './SY',
#   'com/SL',
#   '무엇/NP',
#   '보다/JKB',
#   '아무래도/MAG',
#   '매일/MAG',
#   '진행/NNG',
#   '하/XSV',
#   '는/ETM',
#   '온열/NNG',
#   '요법/NNG',
#   '과정/NNG',
#   '중/NNB',
#   '에서/JKB',
#   '흘리/VV',
#   '는/ETM',
#   '땀/NNG',
#   '의/JKG',
#   '양/NNG',
#   '이/JKS',
#   '제법/MAG',
#   '되/VV',
#   '다/EC',
#   '보/VX',
#   '니/EC',
#   '겨울/NNG',
#   '에/JKB',
#   '도/JX',
#   '무리없이/MAG',
#   '물/NNG',
#   '마시/VV',
#   '는/ETM',
#   '양/NNG',
#   '을/JKO',
#   '높/VA',
#   '게/EC',
#   '잡/VV',
#   '을/ETM',
#   '수/NNB',
#   '있/VV',
#   '는/ETM',
#   '것/NNB',
#   '같/VA',
#   '습니다/EF',
#   './SF',
#   '사실/MAG',
#   '겨울/NNG',
#   '에/JKB',
#   '는/JX',
#   '물/NNG',
#   '마시/VV',
#   '는/ETM',
#   '양/NNB',
#   '이/JKS',
#   '줄어드/VV',
#   '는/ETM',
#   '것/NNB',
#   '이/JKS',
#   '맞/VV',
#   '습니다/EF',
#   './SF',
#   '접촉/NNG',
#   '성/XSN',
#   '피부염/NNG',
#   '지루/XR',
#   '성/XSN',
#   '피부염/NNG',
#   '화장품/NNG',
#   '부작용/NNG',
#   '이/NR',
#   '점/NNBC',
#   '감안/NNG',
#   '하/XSV',
#   '시/EP',
#   '고/EC',
#   '어제/NNG',
#   '와/JKB',
#   '오늘/MAG',
#   '포스팅/NNP',
#   '을/JKO',
#   '읽/VV',
#   '어/EC',
#   '내려가/VV',
#   '시/EP',
#   '면/EC',
#   '도움/NNG',
#   '이/JKS',
#   '되/VV',
#   '지/EC',
#   '않/VX',
#   '을까/EC',
#   '싶/VX',
#   '습니다/EF',
#   './SF',
#   '체중/NNG',
#   '이/JKS',
#   '아주/MAG',
#   '약간/MAG',
#   '씩/XSN',
#   '풀립니다/VV+EF',
#   './SF',
#   '오늘/NNG',
#   '의/JKG',
#   '체중/NNG',
#   '은/JX',
#   '42/SN',
#   './SY',
#   '6/SN',
#   'kg/SL',
#   '2/SN',
#   'L/SL',
#   '에/JKB',
#   '드디어/MAG',
#   '적응/NNG',
#   '이/JKS',
#   '된/VV+ETM',
#   '거/NNB',
#   '니/VCP+EF',
#   '?/SF',
#   '드디어/MAG',
#   '체중/NNG',
#   '이/JKS',
#   '꿈틀/MAG',
#   '꿈틀/MAG',
#   '다시/MAG',
#   '움직이/VV',
#   '는구나/EF',
#   './SF',
#   '../SY',
#   '그/MM',
#   '동안/NNG',
#   '42/SN',
#   './SY',
#   '7/SN',
#   'kg/SL',
#   '맞추/VV',
#   '려고/EC',
#   '일부러/MAG',
#   '화장실/NNG',
#   '2/SN',
#   '번/NNBC',
#   '다녀오/VV',
#   '고/EC',
#   '나/VX',
#   '서/EC',
#   '체중/NNG',
#   '을/JKO',
#   '측정/NNG',
#   '하/XSV',
#   '는/ETM',
#   '등/NNB',
#   '난리/NNG',
#   '를/JKO',
#   '친/VV+ETM',
#   '비하인드/NNG',
#   '스토리/NNG',
#   '가/JKS',
#   '있/VA',
#   '었/EP',
#   '습니다/EF',
#   './SF',
#   '다시/MAG',
#   '움직이/VV',
#   '기/ETN',
#   '시작/NNG',
#   '하/XSV',
#   '는/ETM',
#   '체중/NNG',
#   '을/JKO',
#   '보/VV',
#   '며/EC',
#   ',/SC',
#   '현재/MAG',
#   '쌍/NNG',
#   '끌/VV+ETM',
#   '이/NP',
#   '를/JKO',
#   '매/VV',
#   '고/EC',
#   '기분/NNG',
#   '좋/VA',
#   '게/EC',
#   '걸으며/VV+EC',
#   '식단/NNG',
#   '일지/NNG',
#   '를/JKO',
#   '작성/NNG',
#   '하/XSV',
#   '고/EC',
#   '있/VX',
#   '습니다/EF',
#   './SF',
#   '몸무게/NNG',
#   '때문/NNB',
#   '에/JKB',
#   '물/NNG',
#   '마시/VV',
#   '는/ETM',
#   '양/NNG',
#   '을/JKO',
#   '억지로/MAG',
#   '라도/VCP+EC',
#   '줄여볼까/VV+EC+VX+EC',
#   '하/VV',
#   '다가/EC',
#   '온열/NNG',
#   '요법/NNG',
#   '을/JKO',
#   '좀/MAG',
#   '더/MAG',
#   '빡세/VA',
#   '게/EC',
#   '하/VV',
#   '는/ETM',
#   '쪽/NNB',
#   '으로/JKB',
#   '방향/NNG',
#   '을/JKO',
#   '전환/NNG',
#   '했/XSV+EP',
#   '더니/EC',
#   '몸무게/NNG',
#   '감량/NNG',
#   '효과/NNG',
#   '가/JKS',
#   '있/VA',
#   '는/ETM',
#   '듯/NNB',
#   '합니다/VV+EF',
#   './SF',
#   '드디어/MAG',
#   '체중/NNG',
#   '이/JKS',
#   '움직이/VV',
#   '네요/EF',
#   './SF',
#   'ㅋㅋㅋㅋㅋㅋㅋ/UNKNOWN',
#   '오늘/NNG',
#   '은/JX',
#   '며칠/NNG',
#   '전/NNG',
#   '약속/NNG',
#   '해/XSV+EC',
#   '드린/VX+ETM',
#   '바/NNB',
#   '와/JKB',
#   '같이/MAG',
#   '보습/NNG',
#   '특집/NNG',
#   '나가/VV+EC',
#   '볼까/VX+EC',
#   '합니다/VX+EF',
#   './SF',
#   "'/SY",
#   '보습/NNG',
#   "'/SY",
#   '은/JX',
#   '정말/MAG',
#   '정말/MAG',
#   '정말/MAG',
#   '중요/NNG',
#   '합니다/XSV+EF',
#   './SF',
#   '접촉/NNG',
#   '성/XSN',
#   '피부염/NNG',
#   '지루/XR',
#   '성/XSN',
#   '피부염/NNG',
#   '화장품/NNG',
#   '부작용/NNG',
#   '사실/MAG',
#   '기초/NNG',
#   '제품/NNG',
#   '의/JKG',
#   '가장/MAG',
#   '기본/NNG',
#   '적/XSN',
#   '인/VCP+ETM',
#   '역할/NNG',
#   '이/JKS',
#   '보습/NNG',
#   '이/VCP',
#   '죠/EF',
#   './SF',
#   '보습/NNG',
#   '을/JKO',
#   '위해/VV+EC',
#   '탄생/NNG',
#   '한/XSA+ETM',
#   '것/NNB',
#   '이/JKS',
#   '기초/NNG',
#   '제품/NNG',
#   '인데/VCP+EC',
#   ',/SC',
#   '요즘/MAG',
#   '우리/NP',
#   '는/JX',
#   '보습/NNG',
#   '이외/NNG',
#   '의/JKG',
#   '것/NNB',
#   '들/XSN',
#   '을/JKO',
#   '바라/VV',
#   '는/ETM',
#   '바람/NNB',
#   '에/JKB',
#   '기본/NNG',
#   '을/JKO',
#   '잠시/MAG',
#   '망각/NNG',
#   '하/XSV',
#   '게/EC',
#   '되/VV',
#   '었/EP',
#   '습니다/EF',
#   './SF',
#   '보습/NNG',
#   '이/JKS',
#   '탄탄/XR',
#   '하/XSA',
#   '게/EC',
#   '들어가/VV',
#   '야/EF',
#   '그/MM',
#   '위/NNG',
#   '에/JKB',
#   '미백/NNG',
#   '이/VCP',
#   '든/EC',
#   '탄력/NNG',
#   '이/VCP',
#   '든/EC',
#   '각질/NNG',
#   '정리/NNG',
#   '든/VCP+EC',
#   '주름/NNG',
#   '개선/NNG',
#   '이/VCP',
#   '든/EC',
#   '뭐/NP',
#   '가/JKS',
#   '들어갈/VV+ETM',
#   '수/NNB',
#   '있/VV',
#   '습니다/EF',
#   './SF',
#   '또한/MAJ',
#   '무엇/NP',
#   '보다/JKB',
#   '내/NP+JKG',
#   '피부/NNG',
#   '가/JKS',
#   '그리/MAG',
#   '건강/NNG',
#   '하/XSV',
#   '지/EC',
#   '못하/VX',
#   '다면/EC',
#   ',/SC',
#   '오직/MAG',
#   '보습/NNG',
#   '에/JKB',
#   '만/JX',
#   '포커스/NNG',
#   '를/JKO',
#   '맞추/VV',
#   '세요/EP+EF',
#   './SF',
#   '피부/NNG',
#   '장벽/NNG',
#   '이/JKS',
#   '무너진/VV+ETM',
#   '경우/NNG',
#   '라면/VCP+EC',
#   ',/SC',
#   '오히려/MAJ',
#   '기능/NNG',
#   '성/XSN',
#   '성분/NNG',
#   '이/JKS',
#   '피부/NNG',
#   '에/JKB',
#   '자극/NNG',
#   '을/JKO',
#   '주/VV',
#   '기/ETN',
#   '때문/NNB',
#   '에/JKB',
#   '더/MAG',
#   '피부/NNG',
#   '건강/NNG',
#   '을/JKO',
#   '악화/NNG',
#   '시킬/XSV+ETM',
#   '수/NNB',
#   '있/VV',
#   '습니다/EF',
#   './SF',
#   '사실/MAG',
#   '보습/NNG',
#   '만/JX',
#   '잘/MAG',
#   '이루/VV',
#   '어/EC',
#   '져도/VX+EC',
#   '기본/NNG',
#   '적/XSN',
#   '으로/JKB',
#   '미백/NNG',
#   ',/SC',
#   '탄력/NNG',
#   ',/SC',
#   '각질/NNG',
#   '개선/NNG',
#   ',/SC',
#   '주름/NNG',
#   '개선/NNG',
#   '효과/NNG',
#   '가/JKS',
#   '있/VA',
#   '습니다/EF',
#   './SF',
#   '우리/NP',
#   'back/SL',
#   'to/SL',
#   'the/SL',
#   'basic/SL',
#   '기본/NNG',
#   '으로/JKB',
#   '돌아갑시다/VV+EF',
#   './SF',
#   '피부/NNG',
#   '장벽/NNG',
#   '의/JKG',
#   '이해/NNG',
#   ',/SC',
#   '내/NP+JKG',
#   '피부/NNG',
#   '대체/MAG',
#   '왜/MAG',
#   '이렇게/MAG',
#   '된/VV+ETM',
#   '걸까/NNB+VCP+EC+VCP',
#   '(/SSO',
#   '그/MM',
#   '이유/NNG',
#   '알려/VV+EC',
#   '주/VX',
#   '겠/EP',
#   '어/EF',
#   '!/SF',
#   ')/SSC',
#   '안녕/NNG',
#   '하/XSV',
#   '세요/EP+EF',
#   '청초/NNG',
#   '라/VCP+EC',
#   '음/IC',
#   '주인장/NNG',
#   '라희/NNP',
#   '입니다/VCP+EF',
#   ':/SC',
#   ')/SSC',
#   '피부/NNG',
#   '장벽/NNG',
#   '의/JKG',
#   '이해/NNG',
#   '제/XPN',
#   '체중/NNG',
#   '이/JKS',
#   '요즘/MAG',
#   '살짝/MAG',
#   '오르/VV',
#   '는/ETM',
#   '듯/NNB',
#   '한/XSA+ETM',
#   '현상/NNG',
#   '을/JKO',
#   '저/NP',
#   '는/JX',
#   './SF',
#   '../SY',
#   'm/SL',
#   './SY',
#   'blog/SL',
#   './SY',
#   'naver/SL',
#   './SY',
#   'com/SL',
#   '며칠/NNG',
#   '전/NNG',
#   '큰/VA+ETM',
#   '사랑/NNG',
#   '을/JKO',
#   '받/VV',
#   '았/EP',
#   '던/ETM',
#   '피부/NNG',
#   '장벽/NNG',
#   '의/JKG',
#   '이해/NNG',
#   '포스팅/NNP',
#   './SF',
#   '이/MM',
#   '포스팅/NNP',
#   '을/JKO',
#   '만약/NNG',
#   '읽/VV',
#   '지/EC',
#   '않/VX',
#   '으셨다면/EP+EP+EC',
#   ',/SC',
#   '꼭/MAG',
#   '읽/VV',
#   '고/EC',
#   '보습/NNG',
#   '제품/NNG',
#   '추천/NNG',
#   '포스팅/NNP',
#   '을/JKO',
#   '읽/VV',
#   '어/EC',
#   '내려가/VV',
#   '셨/EP+EP',
#   '음/ETN',
#   '합니다/VV+EF',
#   './SF',
#   '위/IC',
#   '포스팅/NNP',
#   '에/JKB',
#   '기재/NNG',
#   '했/XSV+EP',
#   '다시피/EC',
#   ',/SC',
#   '피부/NNG',
#   '장벽/NNG',
#   '이/JKS',
#   '무너지/VV',
#   '면/EC',
#   '피부/NNG',
#   '가/JKS',
#   '극심/XR',
#   '하/XSA',
#   '게/EC',
#   '건조/NNG',
#   '해집니다/XSA+EC+VX+EF',
#   './SF',
#   '게다가/MAG',
#   '건조/NNG',
#   '한/XSA+ETM',
#   '피부/NNG',
#   '를/JKO',
#   '어떻게/MAG',
#   '든/VV+ETM',
#   '보호/NNG',
#   '하/XSV',
#   '고자/EC',
#   '피/VV',
#   '지/EC',
#   '분/VX+ETM',
#   '비량/NNG',
#   '을/JKO',
#   '엄청나/VA',
#   '게/EC',
#   '늘리/VV',
#   '게/EC',
#   '됩니다/VV+EF',
#   './SF',
#   '접촉/NNG',
#   '성/XSN',
#   '피부염/NNG',
#   '지루/XR',
#   '성/XSN',
#   '피부염/NNG',
#   '화장품/NNG',
#   '부작용/NNG',
#   '피지/NNG',
#   '는/JX',
#   '산성/NNG',
#   '이/VCP',
#   '죠/EF',
#   './SF',
#   '피부/NNG',
#   '장벽/NNG',
#   '이/JKS',
#   '무너지/VV',
#   '면/EC',
#   ',/SC',
#   '유해/NNG',
#   '균/NNG',
#   '과/JC',
#   '알레르기/NNG',
#   '를/JKO',
#   '일으키/VV',
#   '는/ETM',
#   '물질/NNG',
#   '로부터/JKB',
#   '피부/NNG',
#   '를/JKO',
#   '보호/NNG',
#   '하/XSV',
#   '고자/EC',
#   '기름/NNG',
#   '막/NNG',
#   '과/JC',
#   '약산성/NNG',
#   '환경/NNG',
#   '을/JKO',
#   '유지/NNG',
#   '시키/XSV',
#   '기/ETN',
#   '위해/VV+EC',
#   '피/VV',
#   '지/EC',
#   '분/VX+ETM',
#   '비량/NNG',
#   '이/JKS',
#   '늘어나/VV',
#   '게/EC',
#   '됩니다/VV+EF',
#   './SF',
#   '제/NP',
#   '가/JKS',
#   '지루/XR',
#   '성/XSN',
#   '피부염/NNG',
#   '으로/JKB',
#   '극심/XR',
#   '하/XSA',
#   '게/EC',
#   '고생/NNG',
#   '했/XSV+EP',
#   '을/ETM',
#   '때/NNG',
#   ',/SC',
#   '정말/MAG',
#   '피지/NNG',
#   '분/NNB',
#   '비량/NNG',
#   '이/JKS',
#   '말/NNG',
#   '도/JX',
#   '못/MAG',
#   '했/VV+EP',
#   '습니다/EF',
#   './SF',
#   '머리/NNG',
#   '와/JC',
#   '얼굴/NNG',
#   '이/JKS',
#   '다/MAG',
#   '떡/NNG',
#   '지니/NNP',
#   ',/SC',
#   '매일/MAG',
#   '열심히/MAG',
#   '샴푸/NNG',
#   '하/XSV',
#   '고/EC',
#   '비누/NNG',
#   '로/JKB',
#   '세안/NNG',
#   '을/JKO',
#   '꼼꼼히/MAG',
#   '할/VV+ETM',
#   '수/NNB',
#   '밖에/JX',
#   '없/VA',
#   '었/EP',
#   '는데요/EF',
#   './SF',
#   '악순환/NNG',
#   '이/VCP',
#   '더군요/EF',
#   './SF',
#   '제거/NNG',
#   '하/XSV',
#   '면/EC',
#   '또/MAG',
#   '생기/VV',
#   '고/EC',
#   '제거/NNG',
#   '하/XSV',
#   '면/EC',
#   '더/MAG',
#   '생기/VV',
#   '고/EC',
#   '-_-/SY',
#   '머리/NNG',
#   '는/JX',
#   '또/MAG',
#   '어찌나/MAG',
#   '많이/MAG',
#   '빠지/VV',
#   '던지요/EF',
#   './SF',
#   '진짜/MAG',
#   '이대로/MAG',
#   '머리/NNG',
#   '가/JKS',
#   '계속/NNG',
#   '해서/XSV+EC',
#   '빠지/VV',
#   '면/EC',
#   '대머리/NNG',
#   '가/JKS',
#   '될/VV+ETM',
#   '것/NNB',
#   '같/VA',
#   '아/EC',
#   '얼마나/MAG',
#   '불안/NNG',
#   '했/XSV+EP',
#   '는지/EC',
#   '모릅니다/VV+EF',
#   './SF',
#   '게다가/MAG',
#   '피부/NNG',
#   '에/JKB',
#   '짤/VV+ETM',
#   '수/NNB',
#   '도/JX',
#   '없/VA',
#   '는/ETM',
#   '이상/NNG',
#   '한/XSA+ETM',
#   '화농성/NNG',
#   '여드름/NNG',
#   '이/JKS',
#   '얼마나/MAG',
#   '올라오/VV',
#   '던지요/EF',
#   './SF',
#   '결국/MAG',
#   '도저히/MAG',
#   '안/MAG',
#   '되/VV',
#   '겠/EP',
#   '다/EC',
#   '싶/VX',
#   '어/EC',
#   '코코넛/NNG',
#   '오일/NNG',
#   '이나/JC',
#   '100/SN',
#   '%/SY',
#   '천연/NNG',
#   '화장품/NNG',
#   '을/JKO',
#   '대신/NNG',
#   '발랐/VV+EP',
#   '다가/EC',
#   '접촉/NNG',
#   '성/XSN',
#   '피부염/NNG',
#   '진단/NNG',
#   '받/VV',
#   '고/EC',
#   '약/NNG',
#   '을/JKO',
#   '먹/VV',
#   '는데/EC',
#   '약/NNG',
#   '도/JX',
#   ...],
#  [])

# %%
cl.classify(['/'.join(token) for token in pos_tagger.pos('사랑')])

# %%
os.path.dirname
# Out:
# <function posixpath.dirname>
